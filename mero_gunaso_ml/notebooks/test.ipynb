# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('../data/geography/geography.csv')
df
# Out:
#       ward_number                     municipality district  \
# 0               1           Shadanand Municipality  Bhojpur
# 1               2           Shadanand Municipality  Bhojpur
# 2               3           Shadanand Municipality  Bhojpur
# 3               4           Shadanand Municipality  Bhojpur
# 4               5           Shadanand Municipality  Bhojpur
# ...           ...                              ...      ...
# 6738           15  Dhangadhi Sub-Metropolitan City  Kailali
# 6739           16  Dhangadhi Sub-Metropolitan City  Kailali
# 6740           17  Dhangadhi Sub-Metropolitan City  Kailali
# 6741           18  Dhangadhi Sub-Metropolitan City  Kailali
# 6742           19  Dhangadhi Sub-Metropolitan City  Kailali
#
#                  province
# 0          Koshi Province
# 1          Koshi Province
# 2          Koshi Province
# 3          Koshi Province
# 4          Koshi Province
# ...                   ...
# 6738  Sudur Paschimanchal
# ...

# %%
df['province'].unique()
# Out:
# <StringArray>
# [     'Koshi Province',    'Madhesh Province',             'Bagmati',
#              'Gandaki',             'Lumbini',             'Karnali',
#  'Sudur Paschimanchal']
# Length: 7, dtype: str
