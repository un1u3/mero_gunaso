# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('../data/geography/geography.csv')

# %%
df['province'].unique()
# Out:
# <StringArray>
# [     'Koshi Province',    'Madhesh Province',             'Bagmati',
#              'Gandaki',             'Lumbini',             'Karnali',
#  'Sudur Paschimanchal']
# Length: 7, dtype: str
